# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/im-somewhat-of-a-cybersecurity-analyst-myself/training/uploads/fold_4.csv
# /kaggle/input/im-somewhat-of-a-cybersecurity-analyst-myself/training/uploads/fold_45.csv
# /kaggle/input/im-somewhat-of-a-cybersecurity-analyst-myself/training/uploads/fold_44.csv
# /kaggle/input/im-somewhat-of-a-cybersecurity-analyst-myself/training/uploads/fold_19.csv
# /kaggle/input/im-somewhat-of-a-cybersecurity-analyst-myself/training/uploads/fold_11.csv
# /kaggle/input/im-somewhat-of-a-cybersecurity-analyst-myself/training/uploads/fold_27.csv
# /kaggle/input/im-somewhat-of-a-cybersecurity-analyst-myself/training/uploads/fold_15.csv
# /kaggle/input/im-somewhat-of-a-cybersecurity-analyst-myself/training/uploads/fold_17.csv
# /kaggle/input/im-somewhat-of-a-cybersecurity-analyst-myself/training/uploads/fold_41.csv
# /kaggle/input/im-somewhat-of-a-cybersecurity-analyst-myself/training/uploads/fold_21.csv
# /kaggle/input/im-somewhat-of-a-cybersecurity-analyst-myself/training/uploads/fold_30.csv
# ...

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import os
import glob

# %% [markdown]
# # # concatinating folds

# %%
df_test=pd.read_csv('../input/im-somewhat-of-a-cybersecurity-analyst-myself/test.csv/test.csv')
# Out:
# /opt/conda/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3552: DtypeWarning: Columns (28) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
files=os.path.join("../input/im-somewhat-of-a-cybersecurity-analyst-myself/training/uploads","fold*.csv")

# %%
files=glob.glob(files)

# %%
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
print(df)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/reshape/concat.py:304: DtypeWarning: Columns (28) have mixed types.Specify dtype option on import or set low_memory=False.
#   sort=sort,
#          machine_id security_product_name machine_version       app_version  \
# 0            400000          win8defender     1.1.15100.1   4.18.1807.18075
# 1            400001          win8defender     1.1.15200.1        4.10.209.0
# 2            400002          win8defender     1.1.15100.1   4.18.1806.18062
# 3            400003          win8defender     1.1.15200.1   4.18.1807.18075
# 4            400004          win8defender     1.1.14800.3  4.14.17613.18039
# ...             ...                   ...             ...               ...
# 4999995      999995          win8defender     1.1.15200.1   4.18.1807.18075
# 4999996      999996          win8defender     1.1.14500.5  4.12.17007.18011
# 4999997      999997          win8defender     1.1.14700.5   4.8.10240.16384
# ...

# %%
pd.set_option("display.max_rows",1000)
pd.set_option("display.max_columns",82)

# %%
df
# Out:
#          machine_id security_product_name machine_version       app_version  \
# 0            400000          win8defender     1.1.15100.1   4.18.1807.18075
# 1            400001          win8defender     1.1.15200.1        4.10.209.0
# 2            400002          win8defender     1.1.15100.1   4.18.1806.18062
# 3            400003          win8defender     1.1.15200.1   4.18.1807.18075
# 4            400004          win8defender     1.1.14800.3  4.14.17613.18039
# ...             ...                   ...             ...               ...
# 4999995      999995          win8defender     1.1.15200.1   4.18.1807.18075
# 4999996      999996          win8defender     1.1.14500.5  4.12.17007.18011
# 4999997      999997          win8defender     1.1.14700.5   4.8.10240.16384
# 4999998      999998          win8defender     1.1.15100.1   4.18.1806.18062
# 4999999      999999          win8defender     1.1.15200.1    4.13.17134.228
#
# ...

# %% [markdown]
# # **statistical analysis**

# %%
df.describe()

# %%
df.info()

# %%
df.cov()

# %%
df.corr()

# %%
f_data = pd.DataFrame(df,columns = ['av_status','rtp_state','has_tpm','country_id','os_build','core_count_processer','manufacturer_id','model_id','system_volume_capacity','has_optical_drive','ram_capacity','diagonal_display_size','display_resolution_horizontal','display_resolution_vertical','build_number','machine_id','region_id','geo_id','install_language_identifier','is_protected','number_of_charges_for_battery','is_gamer','model_id.1','aoac_support','av_prod_installed','os_suite','secure_boot_status','name_id','touch_support','pen_support','disk_capacity','s_mode',
                                   'default_browser','uac_luaenable'])

# %%
f_test=pd.DataFrame(df_test,columns=['av_status','rtp_state','has_tpm','country_id','os_build','core_count_processer','manufacturer_id','model_id','system_volume_capacity','has_optical_drive','ram_capacity','diagonal_display_size','display_resolution_horizontal','display_resolution_vertical','build_number','machine_id','region_id','geo_id','install_language_identifier','is_protected','number_of_charges_for_battery','is_gamer','model_id.1','aoac_support','av_prod_installed','os_suite','secure_boot_status','name_id','touch_support','pen_support','disk_capacity','s_mode',
                                   'default_browser','uac_luaenable'])

# %%
df.apply(pd.isnull).sum()/df.shape[0]

# %% [markdown]
# ## filling up the null values

# %%
m2 = f_test['av_status'].mean()
f_test['av_status'].fillna(value=m2,inplace=True)
q2 = f_test['rtp_state'].mean()
f_test['rtp_state'].fillna(value=q2,inplace=True)
p2 = f_test['display_resolution_horizontal'].mean()
f_test['display_resolution_horizontal'].fillna(value=p2,inplace=True)
d2 = f_test['display_resolution_vertical'].mean()
f_test['display_resolution_vertical'].fillna(value=d2,inplace=True)
e2 = f_test['diagonal_display_size'].mean()
f_test['diagonal_display_size'].fillna(value=e2,inplace=True)
g2 = f_test['system_volume_capacity'].mean()
f_test['system_volume_capacity'].fillna(value=g2,inplace=True)
h2 = f_test['manufacturer_id'].mean()
f_test['manufacturer_id'].fillna(value=h2,inplace=True)
x2 = f_test['region_id'].mean()
f_test['region_id'].fillna(value=x2,inplace=True)
u2 = f_test['core_count_processer'].mean()
f_test['core_count_processer'].fillna(value=u2,inplace=True)
v2 = f_test['model_id'].mean()
f_test['model_id'].fillna(value=v2,inplace=True)
w2 = f_test['ram_capacity'].mean()
f_test['ram_capacity'].fillna(value=w2,inplace=True)
w2 = f_test['number_of_charges_for_battery'].mean()
f_test['number_of_charges_for_battery'].fillna(value=w2,inplace=True)
w2 = f_test['av_prod_installed'].mean()
f_test['av_prod_installed'].fillna(value=w2,inplace=True)
w2 = f_test['model_id.1'].mean()
f_test['model_id.1'].fillna(value=w2,inplace=True)
w2 = f_test['is_gamer'].mean()
f_test['is_gamer'].fillna(value=w2,inplace=True)
w2 = f_test['install_language_identifier'].mean()
f_test['install_language_identifier'].fillna(value=w2,inplace=True)
w2 = f_test['aoac_support'].mean()
f_test['aoac_support'].fillna(value=w2,inplace=True)
w2 = f_test['geo_id'].mean()
f_test['geo_id'].fillna(value=w2,inplace=True)
z2 = f_test['is_protected'].mean()
f_test['is_protected'].fillna(value=w2,inplace=True)
z2 = f_test['name_id'].mean()
f_test['name_id'].fillna(value=w2,inplace=True)
z2 = f_test['touch_support'].mean()
f_test['touch_support'].fillna(value=w2,inplace=True)
z2 = f_test['pen_support'].mean()
f_test['pen_support'].fillna(value=w2,inplace=True)
z2 = f_test['name_id'].mean()
f_test['name_id'].fillna(value=w2,inplace=True)
z2 = f_test['name_id'].mean()
f_test['name_id'].fillna(value=w2,inplace=True)
z2 = f_test['name_id'].mean()
f_test['name_id'].fillna(value=w2,inplace=True)
z2 = f_test['name_id'].mean()
f_test['name_id'].fillna(value=w2,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_763/1792142652.py in <module>
# ----> 1 m2 = f_test['av_status'].mean()
#       2 f_test['av_status'].fillna(value=m2,inplace=True)
#       3 q2 = f_test['rtp_state'].mean()
#       4 f_test['rtp_state'].fillna(value=q2,inplace=True)
#       5 p2 = f_test['display_resolution_horizontal'].mean()
#
# NameError: name 'f_test' is not defined

# %%
m2 = f_data['av_status'].mean()
f_data['av_status'].fillna(value=m2,inplace=True)
q2 = f_data['rtp_state'].mean()
f_data['rtp_state'].fillna(value=q2,inplace=True)
p2 = f_data['display_resolution_horizontal'].mean()
f_data['display_resolution_horizontal'].fillna(value=p2,inplace=True)
d2 = f_data['display_resolution_vertical'].mean()
f_data['display_resolution_vertical'].fillna(value=d2,inplace=True)
e2 = f_data['diagonal_display_size'].mean()
f_data['diagonal_display_size'].fillna(value=e2,inplace=True)
g2 = f_data['system_volume_capacity'].mean()
f_data['system_volume_capacity'].fillna(value=g2,inplace=True)
h2 = f_data['manufacturer_id'].mean()
f_data['manufacturer_id'].fillna(value=h2,inplace=True)
x2 = f_data['region_id'].mean()
f_data['region_id'].fillna(value=x2,inplace=True)
u2 = f_data['core_count_processer'].mean()
f_data['core_count_processer'].fillna(value=u2,inplace=True)
v2 = f_data['model_id'].mean()
f_data['model_id'].fillna(value=v2,inplace=True)
w2 = f_data['ram_capacity'].mean()
f_data['ram_capacity'].fillna(value=w2,inplace=True)
w2 = f_data['number_of_charges_for_battery'].mean()
f_data['number_of_charges_for_battery'].fillna(value=w2,inplace=True)
w2 = f_data['av_prod_installed'].mean()
f_data['av_prod_installed'].fillna(value=w2,inplace=True)
w2 = f_data['model_id.1'].mean()
f_data['model_id.1'].fillna(value=w2,inplace=True)
w2 = f_data['is_gamer'].mean()
f_data['is_gamer'].fillna(value=w2,inplace=True)
w2 = f_data['install_language_identifier'].mean()
f_data['install_language_identifier'].fillna(value=w2,inplace=True)
w2 = f_data['aoac_support'].mean()
f_data['aoac_support'].fillna(value=w2,inplace=True)
w2 = f_data['geo_id'].mean()
f_data['geo_id'].fillna(value=w2,inplace=True)
w2 = f_data['is_protected'].mean()
f_data['is_protected'].fillna(value=w2,inplace=True)
z2 = f_data['name_id'].mean()
f_data['name_id'].fillna(value=w2,inplace=True)
z2 = f_data['touch_support'].mean()
f_data['touch_support'].fillna(value=w2,inplace=True)
z2 = f_data['pen_support'].mean()
f_data['pen_support'].fillna(value=w2,inplace=True)
z2 = f_data['name_id'].mean()
f_data['name_id'].fillna(value=w2,inplace=True)
z2 = f_data['name_id'].mean()
f_data['name_id'].fillna(value=w2,inplace=True)
z2 = f_data['name_id'].mean()
f_data['name_id'].fillna(value=w2,inplace=True)
z2 = f_data['name_id'].mean()
f_data['name_id'].fillna(value=w2,inplace=True)

# %%
m2 = f_test['av_status'].median()
f_test['av_status'].fillna(value=m2,inplace=True)
q2 = f_test['rtp_state'].median()
f_test['rtp_state'].fillna(value=q2,inplace=True)
p2 = f_test['display_resolution_horizontal'].median()
f_test['display_resolution_horizontal'].fillna(value=p2,inplace=True)
d2 = f_test['display_resolution_vertical'].median()
f_test['display_resolution_vertical'].fillna(value=d2,inplace=True)
e2 = f_test['diagonal_display_size'].median()
f_test['diagonal_display_size'].fillna(value=e2,inplace=True)
g2 = f_test['system_volume_capacity'].median()
f_test['system_volume_capacity'].fillna(value=g2,inplace=True)
h2 = f_test['manufacturer_id'].median()
f_test['manufacturer_id'].fillna(value=h2,inplace=True)
x2 = f_test['region_id'].median()
f_test['region_id'].fillna(value=x2,inplace=True)
u2 = f_test['core_count_processer'].median()
f_test['core_count_processer'].fillna(value=u2,inplace=True)
v2 = f_test['model_id'].median()
f_test['model_id'].fillna(value=v2,inplace=True)
w2 = f_test['ram_capacity'].median()
f_test['ram_capacity'].fillna(value=w2,inplace=True)
w2 = f_test['number_of_charges_for_battery'].median()
f_test['number_of_charges_for_battery'].fillna(value=w2,inplace=True)
w2 = f_test['av_prod_installed'].median()
f_test['av_prod_installed'].fillna(value=w2,inplace=True)
w2 = f_test['model_id.1'].median()
f_test['model_id.1'].fillna(value=w2,inplace=True)
w2 = f_test['is_gamer'].median()
f_test['is_gamer'].fillna(value=w2,inplace=True)
w2 = f_test['install_language_identifier'].median()
f_test['install_language_identifier'].fillna(value=w2,inplace=True)
w2 = f_test['aoac_support'].median()
f_test['aoac_support'].fillna(value=w2,inplace=True)
w2 = f_test['geo_id'].median()
f_test['geo_id'].fillna(value=w2,inplace=True)
w2 = f_test['is_protected'].median()
f_test['is_protected'].fillna(value=w2,inplace=True)
w2 = f_test['name_id'].median()
f_test['name_id'].fillna(value=w2,inplace=True)
w2 = f_test['disk_capacity'].median()
f_test['disk_capacity'].fillna(value=w2,inplace=True)
w2 = f_test['s_mode'].median()
f_test['s_mode'].fillna(value=w2,inplace=True)
w2 = f_test['default_browser'].median()
f_test['default_browser'].fillna(value=w2,inplace=True)
w2 = f_test['uac_luaenable'].median()
f_test['uac_luaenable'].fillna(value=w2,inplace=True)
w2 = f_test['is_protected'].median()
f_test['is_protected'].fillna(value=w2,inplace=True)

# %%
m2 = f_data['av_status'].median()
f_data['av_status'].fillna(value=m2,inplace=True)
q2 = f_data['rtp_state'].median()
f_data['rtp_state'].fillna(value=q2,inplace=True)
p2 = f_data['display_resolution_horizontal'].median()
f_data['display_resolution_horizontal'].fillna(value=p2,inplace=True)
d2 = f_data['display_resolution_vertical'].median()
f_data['display_resolution_vertical'].fillna(value=d2,inplace=True)
e2 = f_data['diagonal_display_size'].median()
f_data['diagonal_display_size'].fillna(value=e2,inplace=True)
g2 = f_data['system_volume_capacity'].median()
f_data['system_volume_capacity'].fillna(value=g2,inplace=True)
h2 = f_data['manufacturer_id'].median()
f_data['manufacturer_id'].fillna(value=h2,inplace=True)
x2 = f_data['region_id'].median()
f_data['region_id'].fillna(value=x2,inplace=True)
u2 = f_data['core_count_processer'].median()
f_data['core_count_processer'].fillna(value=u2,inplace=True)
v2 = f_data['model_id'].median()
f_data['model_id'].fillna(value=v2,inplace=True)
w2 = f_data['ram_capacity'].median()
f_data['ram_capacity'].fillna(value=w2,inplace=True)
w2 = f_data['number_of_charges_for_battery'].median()
f_data['number_of_charges_for_battery'].fillna(value=w2,inplace=True)
w2 = f_data['av_prod_installed'].median()
f_data['av_prod_installed'].fillna(value=w2,inplace=True)
w2 = f_data['model_id.1'].median()
f_data['model_id.1'].fillna(value=w2,inplace=True)
w2 = f_data['is_gamer'].median()
f_data['is_gamer'].fillna(value=w2,inplace=True)
w2 = f_data['install_language_identifier'].median()
f_data['install_language_identifier'].fillna(value=w2,inplace=True)
w2 = f_data['aoac_support'].median()
f_data['aoac_support'].fillna(value=w2,inplace=True)
w2 = f_data['geo_id'].median()
f_data['geo_id'].fillna(value=w2,inplace=True)
w2 = f_data['is_protected'].median()
f_data['is_protected'].fillna(value=w2,inplace=True)
w2 = f_data['name_id'].median()
f_data['name_id'].fillna(value=w2,inplace=True)
w2 = f_data['disk_capacity'].median()
f_data['disk_capacity'].fillna(value=w2,inplace=True)
w2 = f_data['s_mode'].median()
f_data['s_mode'].fillna(value=w2,inplace=True)
w2 = f_data['default_browser'].median()
f_data['default_browser'].fillna(value=w2,inplace=True)
w2 = f_data['uac_luaenable'].median()
f_data['uac_luaenable'].fillna(value=w2,inplace=True)
w2 = f_data['is_protected'].median()
f_data['is_protected'].fillna(value=w2,inplace=True)

# %%
f_test.apply(pd.isnull).sum()/f_test.shape[0]

# %%
f_data.apply(pd.isnull).sum()/f_data.shape[0]

# %%
f_test.apply(pd.isnull).sum()/f_test.shape[0]

# %%
target = pd.DataFrame(df['malware_status'])

# %%
target.shape

# %%
f_data.shape

# %% [markdown]
# ## train-test split

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
 
X_train, X_test, Y_train, Y_test = train_test_split(f_data, target, test_size=0.22)

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

import catboost as ctb

# %%
X_test.shape

# %%
Y_test.shape

# %% [markdown]
# # cat boost

# %%
model_CBC = ctb.CatBoostClassifier()
model_CBC.fit(X_train, Y_train)
print(model_CBC)

# %%
f_data.shape

# %%
X_test.shape

# %%
Y_test.shape

# %%
y_pred = model_CBC.predict(X_test)
from sklearn.metrics import accuracy_score
predictions = [(value) for value in y_pred]
accuracy = accuracy_score(Y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %%
f_data.head()

# %%
output=model_CBC.predict(f_test)
print(f_test.shape,output.shape)
f1=pd.DataFrame(f_test['machine_id'])
f1['malware_status'] = output
f1.to_csv("predict_final_2.csv",index=False)

# %%
# output = model_CBC.predict(f_test)
# ['malware status'] = output
# df.to_csv("prediict.csv",index=False)
